# %%
import os
import pandas as pd


path = '/Users/ijunhui/Downloads/ubion/프로젝트2/2.크롤링/뉴스/관리기업크롤링/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]

# 경로 안 폴더 안에 .csv로 끝나는 폴더들 선택

# %%
# for문을 통해 폴더안 모든 파일들을 중복제거한 후 합침(단, 같은 틀 이어야 함)
df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i)
    df = pd.concat([df,data])

df = df.drop_duplicates()
df = df.reset_index(drop = True)
# df.to_csv('./data/관리종목크롤링.csv', index=False)
len(df['종목명'].unique())
# Out:
# 186

# %%
df[df['신문사']=='머니투데이언론사 선정']
# Out:
#            종목명          신문사                    시간  \
# 537     코오롱티슈진  머니투데이언론사 선정   2019.04.10. 오후 2:52
# 555     코오롱티슈진  머니투데이언론사 선정   2019.05.03. 오후 6:25
# 615     코오롱티슈진  머니투데이언론사 선정   2019.05.07. 오후 5:42
# 5867      바이오빌  머니투데이언론사 선정  2019.01.18. 오후 12:40
# 5878      바이오빌  머니투데이언론사 선정   2019.01.25. 오전 8:48
# 7624       신라젠  머니투데이언론사 선정   2020.01.07. 오후 1:47
# 7695       신라젠  머니투데이언론사 선정   2020.02.05. 오후 3:40
# 7726       신라젠  머니투데이언론사 선정  2020.02.06. 오전 11:00
# 7737       신라젠  머니투데이언론사 선정   2020.02.07. 오전 4:30
# 8746      경남제약  머니투데이언론사 선정  2018.12.15. 오전 10:08
# 8792      경남제약  머니투데이언론사 선정   2018.12.16. 오후 5:00
# 8796      경남제약  머니투데이언론사 선정   2018.12.16. 오후 5:46
# 8849      경남제약  머니투데이언론사 선정   2018.12.17. 오후 6:08
# 8870      경남제약  머니투데이언론사 선정  2018.12.27. 오전 11:46
# 8895      경남제약  머니투데이언론사 선정   2019.01.06. 오후 6:26
# 10804  코오롱생명과학  머니투데이언론사 선정   2019.04.01. 오후 1:44
# 10977  코오롱생명과학  머니투데이언론사 선정   2019.05.15. 오전 7:45
# 14510   매직마이크로  머니투데이언론사 선정   2020.06.29. 오후 5:40
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/ijunhui/Downloads/ubion/프로젝트2/3_크롤링전처리/관리/뉴스/최종_관리_뉴스+닉변.csv')
df
# Out:
#          종목명    신문사                    시간  \
# 0         썬텍  머니투데이  2018.05.16. 오전 11:09
# 1         썬텍   한국경제  2018.05.16. 오전 11:15
# 2         썬텍   이데일리  2018.05.16. 오전 11:17
# 3         썬텍  헤럴드경제  2018.05.16. 오전 11:19
# 4         썬텍   서울경제  2018.05.16. 오전 11:40
# ...      ...    ...                   ...
# 19359  미스터피자   이데일리   2018.04.14. 오후 9:24
# 19360  미스터피자   이데일리   2018.04.14. 오후 9:24
# 19361  미스터피자   이데일리   2018.04.14. 오후 9:24
# 19362  미스터피자   이데일리   2018.04.14. 오후 9:24
# 19363  미스터피자   이데일리   2018.04.14. 오후 9:24
#
#                                           제목  \
# 0             썬텍, 63억웜 규모 경기 화성시 소재 토지 매입 결정
# 1                 썬텍, 63억 규모 경기 화성시 토지 양수 결정
# 2                          썬텍, 경기 화성 유형자산 취득
# 3      [생생코스닥]썬텍, 63억 규모 경기도 화성시 소재 토지 매입 결정
# 4                   썬텍, 63억원 규모 경기 화성시 토지 양수
# ...                                      ...
# 19359             [포토]캠퍼들 환호성 자아내는 미스터피자 드림팀
# 19360               [포토]렛츠 고 캠핑 찾은 미스터피자 드림팀
# ...

# %%
# 신문사 이름 중 ~언른사 선정 을 같은 언론사로 통합
for i in range (0, len(df)):
   df.loc[i]['신문사'] = df.loc[i]['신문사'].replace("언론사 선정", "")

# %%
df['종목명'].nunique()
# Out:
# 244

# %%
df[df['신문사']=='머니투데이언론사 선정']
# Out:
# Empty DataFrame
# Columns: [종목명, 신문사, 시간, 제목, 본문]
# Index: []

# %%
# 그룹화 한 후 기사 수 10개 이하 제거

df_s = df.groupby('종목명').count()
df_1 = df_s.sort_values('신문사', ascending=True)
df_1
# Out:
#            신문사    시간    제목    본문
# 종목명
# 동양시멘트        1     1     1     1
# 디아크          1     1     1     1
# 에스비아이글로벌     1     1     1     1
# 케이제이프리텍      1     1     1     1
# 엠젠플러스        1     1     1     1
# ...        ...   ...   ...   ...
# SK컴즈       266   266   266   266
# 코오롱생명과학    305   305   305   305
# 신라젠        342   342   342   342
# 경남제약       371   371   371   371
# 쌍용건설      1120  1120  1120  1120
#
# [244 rows x 4 columns]

# %%
df_2 = df_1[df_1['신문사'] < 10]
# Out:
# Index(['동양시멘트', '디아크', '에스비아이글로벌', '케이제이프리텍', '엠젠플러스', 'THQ', '코세스',
#        '에스모머티리얼즈', '에이치디', '조이맥스', 'JH코오스', '케이엔씨글로벌', '참존글로벌', '매커스', 'KD',
#        '스틸앤리소시즈', '씨앤에스테크놀로지', '모다'],
#       dtype='object', name='종목명')

# %%
list = ['디아크', '퓨전', '네이처셀', '에이루트', '코세스', '한국가구', '해피드림', '럭슬', '에이치디',
       '케이엔씨글로벌', 'JH코오스', '참존글로벌', '동일철강', '모다', 'WI', '케이에스피', '지디', 'CU전자',
       '액션스퀘어']

# %%
len(list)
# Out:
# 19

# %%
len(df['종목명'].unique())
# Out:
# 244

# %%
df_df = df[~df['종목명'].isin(list)]

# %%
len(df_df['종목명'].unique())
# Out:
# 237

# %%
df_df
df_df.to_csv('/Users/ijunhui/Downloads/ubion/프로젝트2/3_크롤링전처리/관리/뉴스/최종_관리_뉴스+닉변.csv', index=False)

# %%
len(df_df['종목명'].unique())
# Out:
# 237
